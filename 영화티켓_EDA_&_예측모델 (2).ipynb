# %%
import pandas as pd

df = pd.read_csv('/content/cinemaTicket_Ref.csv')
df
# Out:
#         film_code  cinema_code  total_sales  tickets_sold  tickets_out  \
# 0            1492          304      3900000            26            0
# 1            1492          352      3360000            42            0
# 2            1492          489      2560000            32            0
# 3            1492          429      1200000            12            0
# 4            1492          524      1200000            15            0
# ...           ...          ...          ...           ...          ...
# 106418       1482          529      1200000            10            0
# 106419       1482          522      1080000             9            0
# 106420       1482           50       900000             9            0
# 106421       1482          338       640000             8            0
# 106422       1482          431       600000             6            0
#
#         show_time  occu_perc  ticket_price  ticket_use    capacity  \
# 0               4       4.26      150000.0          26  610.328638
# 1               5       8.08       80000.0          42  519.801980
# 2               4      20.00       80000.0          32  160.000000
# 3               1      11.01      100000.0          12  108.991826
# 4               3      16.67       80000.0          15   89.982004
# ...           ...        ...           ...         ...         ...
# 106418          4       5.56      120000.0          10  179.856115
# 106419          3       3.53      120000.0           9  254.957507
# 106420          3       1.69      100000.0           9  532.544379
# 106421          1       3.25       80000.0           8  246.153846
# 106422          8       1.37      100000.0           6  437.956204
#
#               date  month  quarter   day
# 0       2018-05-05    5.0      2.0   5.0
# 1       2018-05-05    5.0      2.0   5.0
# 2       2018-05-05    5.0      2.0   5.0
# 3       2018-05-05    5.0      2.0   5.0
# 4       2018-05-05    5.0      2.0   5.0
# ...            ...    ...      ...   ...
# 106418  2018-03-18    3.0      1.0  18.0
# 106419  2018-03-18    3.0      1.0  18.0
# 106420  2018-03-18    3.0      1.0  18.0
# 106421  2018-03-18    3.0      1.0  18.0
# 106422         NaN    NaN      NaN   NaN
#
# [106423 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['film_code', 'cinema_code', 'total_sales', 'tickets_sold',
#        'tickets_out', 'show_time', 'occu_perc', 'ticket_price', 'ticket_use',
#        'capacity', 'date', 'month', 'quarter', 'day'],
#       dtype='object')

# %% [markdown]
# 타겟 변수 : total_sales

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106423 entries, 0 to 106422
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   film_code     106423 non-null  int64
#  1   cinema_code   106423 non-null  int64
#  2   total_sales   106423 non-null  int64
#  3   tickets_sold  106423 non-null  int64
#  4   tickets_out   106423 non-null  int64
#  5   show_time     106423 non-null  int64
#  6   occu_perc     106331 non-null  float64
#  7   ticket_price  106423 non-null  float64
#  8   ticket_use    106423 non-null  int64
#  9   capacity      106331 non-null  float64
#  10  date          106422 non-null  object
#  11  month         106422 non-null  float64
#  12  quarter       106422 non-null  float64
#  13  day           106422 non-null  float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 11.4+ MB

# %%
df.isnull().sum()
# Out:
# film_code        0
# cinema_code      0
# total_sales      0
# tickets_sold     0
# tickets_out      0
# show_time        0
# occu_perc       92
# ticket_price     0
# ticket_use       0
# capacity        92
# date             1
# month            1
# quarter          1
# day              1
# dtype: int64

# %%
mean1 = df['occu_perc'].mean()
mean2 = df['capacity'].mean()
df['occu_perc'].fillna(mean1, inplace=True)
df['capacity'].fillna(mean2, inplace=True)
df.isnull().sum()
# Out:
# film_code       0
# cinema_code     0
# total_sales     0
# tickets_sold    0
# tickets_out     0
# show_time       0
# occu_perc       0
# ticket_price    0
# ticket_use      0
# capacity        0
# date            1
# month           1
# quarter         1
# day             1
# dtype: int64

# %%
#1. 결측치 삭제 후 모델링 진행
#df1 = df.copy()
#df1.dropna(axis=0, inplace=True)
#df1.isnull().sum()

# %%
#월별 상영 횟수 시각화
df_count = df.groupby('month')['show_time'].sum().reset_index()
df_count['month'] = df_count['month'].astype('str').str.split('.').str[0]
df_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month      10 non-null     object
#  1   show_time  10 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 288.0+ bytes

# %%
df_count
# Out:
#   month  show_time
# 0     2          3
# 1     3      33645
# 2     4      49443
# 3     5      49262
# 4     6      47215
# 5     7      66528
# 6     8      64237
# 7     9      41613
# 8    10      66336
# 9    11       6772

# %%
# !pip install kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaleido in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
import kaleido

# %%
import plotly.express as px
import plotly.io as pio

fig = px.bar(df_count, x='month', y='show_time', color='month', text='show_time', title='월별 상영 횟수 시각화')
fig.show(render = "png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a69cdafc-8233-45ab-b663-c0a83843e3fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a69cdafc-8233-45ab-b663-c0a83843e3fc")) {                    Plotly.newPlot(                        "a69cdafc-8233-45ab-b663-c0a83843e3fc",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"text":[3.0],"textposition":"auto","x":["2"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"3","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"v","showlegend":true,"text":[33645.0],"textposition":"auto","x":["3"],"xaxis":"x","y":[33645],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"4","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"v","showlegend":true,"text":[49443.0],"textposition":"auto","x":["4"],"xaxis":"x","y":[49443],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"5","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"5","offsetgroup":"5","orientation":"v","showlegend":true,"text":[49262.0],"textposition":"auto","x":["5"],"xaxis":"x","y":[49262],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"6","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"6","offsetgroup":"6","orientation":"v","showlegend":true,"text":[47215.0],"textposition":"auto","x":["6"],"xaxis":"x","y":[47215],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"7","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"7","offsetgroup":"7","orientation":"v","showlegend":true,"text":[66528.0],"textposition":"auto","x":["7"],"xaxis":"x","y":[66528],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"8","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"8","offsetgroup":"8","orientation":"v","showlegend":true,"text":[64237.0],"textposition":"auto","x":["8"],"xaxis":"x","y":[64237],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"9","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"9","offsetgroup":"9","orientation":"v","showlegend":true,"text":[41613.0],"textposition":"auto","x":["9"],"xaxis":"x","y":[41613],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"10","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"10","offsetgroup":"10","orientation":"v","showlegend":true,"text":[66336.0],"textposition":"auto","x":["10"],"xaxis":"x","y":[66336],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"11","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"11","offsetgroup":"11","orientation":"v","showlegend":true,"text":[6772.0],"textposition":"auto","x":["11"],"xaxis":"x","y":[6772],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity" ...

# %%
#월별 판매 티켓 수 시각화
df3 = df.groupby('month')['tickets_sold'].sum().reset_index()
df3['month'] = df3['month'].astype('str').str.split('.').str[0] + '월'
df3
# Out:
#   month  tickets_sold
# 0    2월           270
# 1    3월       1832905
# 2    4월       4134613
# 3    5월       3052733
# 4    6월       1249595
# 5    7월       2992026
# 6    8월       2851380
# 7    9월       1074979
# 8   10월       2563955
# 9   11월        220511

# %%
fig = px.pie(df3, values='tickets_sold', names = 'month', color = 'month', title='월별 판매 티켓 수 시각화')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="daf13e4f-ff7b-43f0-a1a0-e938f3518494" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daf13e4f-ff7b-43f0-a1a0-e938f3518494")) {                    Plotly.newPlot(                        "daf13e4f-ff7b-43f0-a1a0-e938f3518494",                        [{"customdata":[["2\uc6d4"],["3\uc6d4"],["4\uc6d4"],["5\uc6d4"],["6\uc6d4"],["7\uc6d4"],["8\uc6d4"],["9\uc6d4"],["10\uc6d4"],["11\uc6d4"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"month=%{customdata[0]}<br>tickets_sold=%{value}<extra></extra>","labels":["2\uc6d4","3\uc6d4","4\uc6d4","5\uc6d4","6\uc6d4","7\uc6d4","8\uc6d4","9\uc6d4","10\uc6d4","11\uc6d4"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52"]},"name":"","showlegend":true,"values":[270,1832905,4134613,3052733,1249595,2992026,2851380,1074979,2563955,220511],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorba ...

# %%
#월별 수익 시각화 
df4 = df.groupby('month')['total_sales'].sum().reset_index()
df4['month'] = df4['month'].astype('str').str.split('.').str[0]+'월'
df4
# Out:
#   month   total_sales
# 0    2월      32210000
# 1    3월  193433625732
# 2    4월  348614664007
# 3    5월  239595373317
# 4    6월  104001473893
# 5    7월  264855462688
# 6    8월  258296800764
# 7    9월   96569594964
# 8   10월  231675849820
# 9   11월   22708024998

# %%
fig = px.line(df4, x='month', y='total_sales', title='월별 수익 시각화')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0d7b3e53-0f3a-40fb-ab31-3d3f87771ed0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d7b3e53-0f3a-40fb-ab31-3d3f87771ed0")) {                    Plotly.newPlot(                        "0d7b3e53-0f3a-40fb-ab31-3d3f87771ed0",                        [{"hovertemplate":"month=%{x}<br>total_sales=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2\uc6d4","3\uc6d4","4\uc6d4","5\uc6d4","6\uc6d4","7\uc6d4","8\uc6d4","9\uc6d4","10\uc6d4","11\uc6d4"],"xaxis":"x","y":[32210000,193433625732,348614664007,239595373317,104001473893,264855462688,258296800764,96569594964,231675849820,22708024998],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[ ...

# %%
df.columns
# Out:
# Index(['film_code', 'cinema_code', 'total_sales', 'tickets_sold',
#        'tickets_out', 'show_time', 'occu_perc', 'ticket_price', 'ticket_use',
#        'capacity', 'date', 'month', 'quarter', 'day'],
#       dtype='object')

# %%
df.film_code.unique()
# Out:
# array([1492, 1567, 1497, 1498, 1494, 1486, 1496, 1511, 1563, 1589, 1566,
#        1550, 1499, 1551, 1558, 1565, 1568, 1562, 1512, 1575, 1495, 1471,
#        1480, 1559, 1570, 1584, 1587, 1484, 1553, 1573, 1571, 1483, 1552,
#        1576, 1560, 1502, 1554, 1572, 1564, 1557, 1485, 1482, 1481, 1500,
#        1578, 1493, 1556, 1569])

# %%
#영화 코드별 상영 횟수 -> 어떤 영화가 가장 많이 상영됐는지 파악 
df['film_code'] = df['film_code'].astype('str')
df5 = df.groupby('film_code')['show_time'].sum().reset_index()
fig = px.bar(df5, x='film_code', y='show_time', color='film_code', text='show_time', title='영화 코드별 상영 횟수 시각화')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="204dd092-844e-427d-8c1b-133fc51de7e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("204dd092-844e-427d-8c1b-133fc51de7e4")) {                    Plotly.newPlot(                        "204dd092-844e-427d-8c1b-133fc51de7e4",                        [{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1471","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1471","offsetgroup":"1471","orientation":"v","showlegend":true,"text":[1182.0],"textposition":"auto","x":["1471"],"xaxis":"x","y":[1182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1480","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1480","offsetgroup":"1480","orientation":"v","showlegend":true,"text":[4173.0],"textposition":"auto","x":["1480"],"xaxis":"x","y":[4173],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1481","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1481","offsetgroup":"1481","orientation":"v","showlegend":true,"text":[29116.0],"textposition":"auto","x":["1481"],"xaxis":"x","y":[29116],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1482","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1482","offsetgroup":"1482","orientation":"v","showlegend":true,"text":[28747.0],"textposition":"auto","x":["1482"],"xaxis":"x","y":[28747],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1483","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1483","offsetgroup":"1483","orientation":"v","showlegend":true,"text":[30916.0],"textposition":"auto","x":["1483"],"xaxis":"x","y":[30916],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1484","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"1484","offsetgroup":"1484","orientation":"v","showlegend":true,"text":[33488.0],"textposition":"auto","x":["1484"],"xaxis":"x","y":[33488],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1485","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"1485","offsetgroup":"1485","orientation":"v","showlegend":true,"text":[23310.0],"textposition":"auto","x":["1485"],"xaxis":"x","y":[23310],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1486","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"1486","offsetgroup":"1486","orientation":"v","showlegend":true,"text":[8584.0],"textposition":"auto","x":["1486"],"xaxis":"x","y":[8584],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1492","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"1492","offsetgroup":"1492","orientation":"v","showlegend":true,"text":[2917.0],"textposition":"auto","x":["1492"],"xaxis":"x","y":[2917],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>show_time=%{text}<extra></extra>","legendgroup":"1493","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"1493","offsetgroup":"1493","orientation":"v","showlegend":true,"text":[46602.0],"textposition":"auto","x":["1493"],"xaxis":"x","y":[46602],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>s ...

# %%
#영화 코드별 total_sales 시각화 -> 상영횟수가 많은 영화일수록 수익이 높을까? 
df6 = df.groupby('film_code')['total_sales'].sum().reset_index()
fig = px.bar(df6, x='film_code', y='total_sales', color='film_code', text='total_sales', title='영화 코드별 수익 시각화')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ec928e73-45a3-4d88-a326-6c2b63221cde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec928e73-45a3-4d88-a326-6c2b63221cde")) {                    Plotly.newPlot(                        "ec928e73-45a3-4d88-a326-6c2b63221cde",                        [{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1471","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1471","offsetgroup":"1471","orientation":"v","showlegend":true,"text":[2114454998.0],"textposition":"auto","x":["1471"],"xaxis":"x","y":[2114454998],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1480","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1480","offsetgroup":"1480","orientation":"v","showlegend":true,"text":[5310427986.0],"textposition":"auto","x":["1480"],"xaxis":"x","y":[5310427986],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1481","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1481","offsetgroup":"1481","orientation":"v","showlegend":true,"text":[79051516436.0],"textposition":"auto","x":["1481"],"xaxis":"x","y":[79051516436],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1482","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1482","offsetgroup":"1482","orientation":"v","showlegend":true,"text":[130526074406.0],"textposition":"auto","x":["1482"],"xaxis":"x","y":[130526074406],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1483","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1483","offsetgroup":"1483","orientation":"v","showlegend":true,"text":[156913458770.0],"textposition":"auto","x":["1483"],"xaxis":"x","y":[156913458770],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1484","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"1484","offsetgroup":"1484","orientation":"v","showlegend":true,"text":[150941697328.0],"textposition":"auto","x":["1484"],"xaxis":"x","y":[150941697328],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1485","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"1485","offsetgroup":"1485","orientation":"v","showlegend":true,"text":[90877218382.0],"textposition":"auto","x":["1485"],"xaxis":"x","y":[90877218382],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1486","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"1486","offsetgroup":"1486","orientation":"v","showlegend":true,"text":[20172286458.0],"textposition":"auto","x":["1486"],"xaxis":"x","y":[20172286458],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1492","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"1492","offsetgroup":"1492","orientation":"v","showlegend":true,"text":[2084629999.0],"textposition":"auto","x":["1492"],"xaxis":"x","y":[2084629999],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>total_sales=%{text}<extra></extra>","legendgroup":"1493","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"1493","offsetgroup":"1493","orientation":"v","showlegend":true,"text":[144169741258.0],"te ...

# %%
#영화 코드별 상영횟수 대비 티켓 환불율 시각화
df7 = df.groupby('film_code')['tickets_out'].sum().reset_index()
df7['tickets_out_per'] = (df7['tickets_out'] / df5['show_time']).round(2)
fig = px.bar(df7, x='film_code', y='tickets_out_per', color='film_code', text='tickets_out_per', title='영화 코드별 상영 횟수 대비 티켓 환불 비율')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="be93b15a-25c0-4083-befd-a3c0c6be3aff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be93b15a-25c0-4083-befd-a3c0c6be3aff")) {                    Plotly.newPlot(                        "be93b15a-25c0-4083-befd-a3c0c6be3aff",                        [{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1471","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1471","offsetgroup":"1471","orientation":"v","showlegend":true,"text":[0.02],"textposition":"auto","x":["1471"],"xaxis":"x","y":[0.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1480","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1480","offsetgroup":"1480","orientation":"v","showlegend":true,"text":[0.02],"textposition":"auto","x":["1480"],"xaxis":"x","y":[0.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1481","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1481","offsetgroup":"1481","orientation":"v","showlegend":true,"text":[0.09],"textposition":"auto","x":["1481"],"xaxis":"x","y":[0.09],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1482","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1482","offsetgroup":"1482","orientation":"v","showlegend":true,"text":[0.14],"textposition":"auto","x":["1482"],"xaxis":"x","y":[0.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1483","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1483","offsetgroup":"1483","orientation":"v","showlegend":true,"text":[0.05],"textposition":"auto","x":["1483"],"xaxis":"x","y":[0.05],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1484","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"1484","offsetgroup":"1484","orientation":"v","showlegend":true,"text":[0.07],"textposition":"auto","x":["1484"],"xaxis":"x","y":[0.07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1485","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"1485","offsetgroup":"1485","orientation":"v","showlegend":true,"text":[0.05],"textposition":"auto","x":["1485"],"xaxis":"x","y":[0.05],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1486","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"1486","offsetgroup":"1486","orientation":"v","showlegend":true,"text":[0.03],"textposition":"auto","x":["1486"],"xaxis":"x","y":[0.03],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1492","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"1492","offsetgroup":"1492","orientation":"v","showlegend":true,"text":[0.02],"textposition":"auto","x":["1492"],"xaxis":"x","y":[0.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"film_code=%{x}<br>tickets_out_per=%{text}<extra></extra>","legendgroup":"1493","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"1493","offsetgroup":"1493","orientation":"v","showlegend":true,"text":[0.06],"textposition":"auto","x":["1493"],"xaxis":"x","y":[0.06],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hoverte ...

# %%
#모델링 전처리
df
# Out:
#        film_code  cinema_code  total_sales  tickets_sold  tickets_out  \
# 0           1492          304      3900000            26            0
# 1           1492          352      3360000            42            0
# 2           1492          489      2560000            32            0
# 3           1492          429      1200000            12            0
# 4           1492          524      1200000            15            0
# ...          ...          ...          ...           ...          ...
# 142519      1569          495      1320000            22            0
# 142520      1569          474      1200000            15            0
# 142521      1569          524      1060000             8            0
# 142522      1569          529       600000             5            0
# 142523      1569          486       250000             5            0
#
#         show_time  occu_perc  ticket_price  ticket_use    capacity  \
# 0               4       4.26      150000.0          26  610.328638
# 1               5       8.08       80000.0          42  519.801980
# 2               4      20.00       80000.0          32  160.000000
# 3               1      11.01      100000.0          12  108.991826
# 4               3      16.67       80000.0          15   89.982004
# ...           ...        ...           ...         ...         ...
# 142519          2       3.86       60000.0          22  569.948187
# 142520          1      65.22       80000.0          15   22.999080
# 142521          3       9.20      132500.0           8   86.956522
# 142522          2       5.00      120000.0           5  100.000000
# 142523          1       1.79       50000.0           5  279.329609
#
#               date  month  quarter  day
# 0       2018-05-05      5        2    5
# 1       2018-05-05      5        2    5
# 2       2018-05-05      5        2    5
# 3       2018-05-05      5        2    5
# 4       2018-05-05      5        2    5
# ...            ...    ...      ...  ...
# 142519  2018-11-04     11        4    4
# 142520  2018-11-04     11        4    4
# 142521  2018-11-04     11        4    4
# 142522  2018-11-04     11        4    4
# 142523  2018-11-04     11        4    4
#
# [142524 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import  MinMaxScaler

scaler = MinMaxScaler()

df1 = df.drop(columns=['film_code', 'cinema_code', 'date', 'month', 'quarter', 'day'])
Y = df1['total_sales']
df1.drop(columns='total_sales', inplace=True)
train_x, val_x, train_y, val_y = train_test_split(df1, Y, test_size=0.3, random_state=77)
print(train_x.shape, val_x.shape)
# Out:
# (99766, 7) (42758, 7)

# %%
print(train_y.shape, val_y.shape)
# Out:
# (99766,) (42758,)

# %%
train_x
# Out:
#         tickets_sold  tickets_out  show_time  occu_perc   ticket_price  \
# 75321             10            0          1       4.76   36000.000000
# 14150             27            0          3       4.05  100000.000000
# 76485             22            0          2       2.75   70000.000000
# 87791           1927            0          8      64.32   50000.000000
# 126762            66            0          7       3.41  105454.545455
# ...              ...          ...        ...        ...            ...
# 110009            35            0          3      11.90  120000.000000
# 25503             23            0          3       3.45  100000.000000
# 138904            25            0          3       6.51   80000.000000
# 107813           376            0          8      62.67   50000.000000
# 74335              7            0          7       1.56  100000.000000
#
#         ticket_use     capacity
# 75321           10   210.084034
# 14150           27   666.666667
# 76485           22   800.000000
# 87791         1927  2995.957711
# 126762          66  1935.483871
# ...            ...          ...
# 110009          35   294.117647
# 25503           23   666.666667
# 138904          25   384.024578
# 107813         376   599.968087
# 74335            7   448.717949
#
# [99766 rows x 7 columns]

# %%
val_x
# Out:
#         tickets_sold  tickets_out  show_time  occu_perc   ticket_price  \
# 125902           192            0          7      12.22  146093.750000
# 136504            29            0          1       7.71   48275.862069
# 26557            209            0          3      33.49   50000.000000
# 57267              6            0          1      26.09   80000.000000
# 107831           105            0          1      89.74   80000.000000
# ...              ...          ...        ...        ...            ...
# 50591             72            0          4      14.01  150000.000000
# 10409              3            0          3       0.18  100000.000000
# 109842           502            0          4      87.15   40000.000000
# 67258            486            0          4      60.67   79835.390947
# 15718              7            0          4       1.03   30000.000000
#
#         ticket_use     capacity
# 125902         192  1571.194763
# 136504          29   376.134890
# 26557          209   624.066886
# 57267            6    22.997317
# 107831         105   117.004680
# ...            ...          ...
# 50591           72   513.918630
# 10409            3  1666.666667
# 109842         502   576.018359
# 67258          486   801.054887
# 15718            7   679.611650
#
# [42758 rows x 7 columns]

# %%
train = pd.DataFrame(scaler.fit_transform(train_x))
#test = scaler.fit(val_x)

# %%
train.columns = df1.columns
train
# Out:
#        tickets_sold  tickets_out  show_time  occu_perc  ticket_price  \
# 0          0.001141          0.0   0.000000   0.032271      0.049255
# 1          0.003296          0.0   0.033898   0.027458      0.140893
# 2          0.002662          0.0   0.016949   0.018644      0.097938
# 3          0.244168          0.0   0.118644   0.436068      0.069301
# 4          0.008240          0.0   0.101695   0.023119      0.148704
# ...             ...          ...        ...        ...           ...
# 99761      0.004310          0.0   0.033898   0.080678      0.169530
# 99762      0.002789          0.0   0.033898   0.023390      0.140893
# 99763      0.003043          0.0   0.033898   0.044136      0.112257
# 99764      0.047541          0.0   0.118644   0.424881      0.069301
# 99765      0.000761          0.0   0.101695   0.010576      0.140893
#
#        ticket_use  capacity
# 0        0.024997  0.022662
# 1        0.027101  0.071449
# 2        0.026482  0.085696
# 3        0.262220  0.320339
# 4        0.031927  0.207025
# ...           ...       ...
# 99761    0.028091  0.031641
# 99762    0.026606  0.071449
# 99763    0.026853  0.041248
# 99764    0.070288  0.064322
# 99765    0.024626  0.048160
#
# [99766 rows x 7 columns]

# %%
train_y = pd.DataFrame(train_y).reset_index()
train_y.drop(columns=['index'], inplace=True)
train_y
# Out:
#        total_sales
# 0           360000
# 1          2700000
# 2          1540000
# 3         96350000
# 4          6960000
# ...            ...
# 99761      4200000
# 99762      2300000
# 99763      2000000
# 99764     18800000
# 99765       700000
#
# [99766 rows x 1 columns]

# %%
train
# Out:
#        tickets_sold  tickets_out  show_time  occu_perc  ticket_price  \
# 0          0.001141          0.0   0.000000   0.032271      0.049255
# 1          0.003296          0.0   0.033898   0.027458      0.140893
# 2          0.002662          0.0   0.016949   0.018644      0.097938
# 3          0.244168          0.0   0.118644   0.436068      0.069301
# 4          0.008240          0.0   0.101695   0.023119      0.148704
# ...             ...          ...        ...        ...           ...
# 99761      0.004310          0.0   0.033898   0.080678      0.169530
# 99762      0.002789          0.0   0.033898   0.023390      0.140893
# 99763      0.003043          0.0   0.033898   0.044136      0.112257
# 99764      0.047541          0.0   0.118644   0.424881      0.069301
# 99765      0.000761          0.0   0.101695   0.010576      0.140893
#
#        ticket_use  capacity
# 0        0.024997  0.022662
# 1        0.027101  0.071449
# 2        0.026482  0.085696
# 3        0.262220  0.320339
# 4        0.031927  0.207025
# ...           ...       ...
# 99761    0.028091  0.031641
# 99762    0.026606  0.071449
# 99763    0.026853  0.041248
# 99764    0.070288  0.064322
# 99765    0.024626  0.048160
#
# [99766 rows x 7 columns]

# %%
#1. k-fold를 활용한 lightGBM
from sklearn.model_selection import KFold

k_fold = KFold(n_splits=5, shuffle=True, random_state=77)

# %%
for train_idx, val_idx in k_fold.split(train) :
  print(len(train_idx), len(val_idx))
  break
# Out:
# 79812 19954

# %%
import lightgbm as lgb

model = lgb.LGBMRegressor(random_state=77, n_estimators=1000)
models = []
for train_idx, val_idx in k_fold.split(train) : 
  train_x = train.iloc[train_idx]
  y_train = train_y.iloc[train_idx]
  val_x = train.iloc[val_idx]
  val_y = train_y.iloc[val_idx]
  models.append(model.fit(train_x, y_train, eval_set=(val_x, val_y), early_stopping_rounds=100, verbose=100))
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's l2: 6.3645e+12
# [200]	valid_0's l2: 4.42906e+12
# [300]	valid_0's l2: 3.68626e+12
# [400]	valid_0's l2: 3.38097e+12
# [500]	valid_0's l2: 3.23078e+12
# [600]	valid_0's l2: 3.21317e+12
# [700]	valid_0's l2: 3.20461e+12
# Early stopping, best iteration is:
# [614]	valid_0's l2: 3.17955e+12
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's l2: 2.25456e+12
# [200]	valid_0's l2: 2.2703e+12
# Early stopping, best iteration is:
# [136]	valid_0's l2: 2.18485e+12
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's l2: 1.24041e+13
# [200]	valid_0's l2: 8.63207e+12
# [300]	valid_0's l2: 6.46231e+12
# [400]	valid_0's l2: 5.55708e+12
# [500]	valid_0's l2: 5.15211e+12
# [600]	valid_0's l2: 4.73724e+12
# [700]	valid_0's l2: 4.58073e+12
# [800]	valid_0's l2: 4.40395e+12
# [900]	valid_0's l2: 4.28281e+12
# [1000]	valid_0's l2: 4.18499e+12
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 4.18499e+12
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's l2: 7.59178e+12
# [200]	valid_0's l2: 5.95464e+12
# [300]	valid_0's l2: 4.98532e+12
# [400]	valid_0's l2: 4.06963e+12
# [500]	valid_0's l2: 3.63854e+12
# [600]	valid_0's l2: 3.39699e+12
# [700]	valid_0's l2: 3.27271e+12
# [800]	valid_0's l2: 3.12178e+12
# [900]	valid_0's l2: 3.06527e+12
# [1000]	valid_0's l2: 3.01405e+12
# Did not meet early stopping. Best iteration is:
# [990]	valid_0's l2: 3.01283e+12
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's l2: 5.98228e+12
# [200]	valid_0's l2: 5.098e+12
# Early stopping, best iteration is:
# [190]	valid_0's l2: 4.97073e+12

# %%
pred = []
for model in models :
  pred.append(model.predict(val_x))

# %%
pd.DataFrame(pred)
# Out:
#           0             1             2             3             4      \
# 0  1.020634e+08  1.935298e+06  2.443539e+07  1.447457e+06  9.061271e+06
# 1  1.020634e+08  1.935298e+06  2.443539e+07  1.447457e+06  9.061271e+06
# 2  1.020634e+08  1.935298e+06  2.443539e+07  1.447457e+06  9.061271e+06
# 3  1.020634e+08  1.935298e+06  2.443539e+07  1.447457e+06  9.061271e+06
# 4  1.020634e+08  1.935298e+06  2.443539e+07  1.447457e+06  9.061271e+06
#
#           5             6             7              8             9      ...  \
# 0  1.340525e+06  1.316549e+07  3.259564e+06  792740.499124  8.388213e+07  ...
# 1  1.340525e+06  1.316549e+07  3.259564e+06  792740.499124  8.388213e+07  ...
# 2  1.340525e+06  1.316549e+07  3.259564e+06  792740.499124  8.388213e+07  ...
# 3  1.340525e+06  1.316549e+07  3.259564e+06  792740.499124  8.388213e+07  ...
# 4  1.340525e+06  1.316549e+07  3.259564e+06  792740.499124  8.388213e+07  ...
#
#          19943         19944         19945         19946         19947  \
# 0  1640538.533  1.760146e+06  3.234684e+07  1.083495e+07  9.554183e+06
# 1  1640538.533  1.760146e+06  3.234684e+07  1.083495e+07  9.554183e+06
# 2  1640538.533  1.760146e+06  3.234684e+07  1.083495e+07  9.554183e+06
# 3  1640538.533  1.760146e+06  3.234684e+07  1.083495e+07  9.554183e+06
# 4  1640538.533  1.760146e+06  3.234684e+07  1.083495e+07  9.554183e+06
#
#           19948         19949         19950          19951         19952
# 0  9.219374e+06  2.309045e+07  1.845996e+06  344673.409387  4.152501e+06
# 1  9.219374e+06  2.309045e+07  1.845996e+06  344673.409387  4.152501e+06
# 2  9.219374e+06  2.309045e+07  1.845996e+06  344673.409387  4.152501e+06
# 3  9.219374e+06  2.309045e+07  1.845996e+06  344673.409387  4.152501e+06
# 4  9.219374e+06  2.309045e+07  1.845996e+06  344673.409387  4.152501e+06
#
# [5 rows x 19953 columns]

# %%
import numpy as np
val_x['predict'] = np.mean(pred, axis=0).round(0)
val_x = pd.concat([val_x, val_y], axis=1)
val_x
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        tickets_sold  tickets_out  show_time  occu_perc  ticket_price  \
# 3          0.244168     0.000000   0.118644   0.436068      0.069301
# 5          0.006212     0.000000   0.016949   0.156949      0.054983
# 8          0.037399     0.000000   0.101695   0.245017      0.112257
# 9          0.002409     0.000000   0.016949   0.028068      0.097938
# 12         0.018636     0.037736   0.186441   0.022915      0.083620
# ...             ...          ...        ...        ...           ...
# 99743      0.015720     0.000000   0.016949   0.074576      0.100916
# 99749      0.028905     0.000000   0.118644   0.114169      0.142894
# 99750      0.004564     0.000000   0.000000   0.126712      0.069301
# 99754      0.000634     0.000000   0.067797   0.001966      0.069301
# 99761      0.004310     0.000000   0.033898   0.080678      0.169530
#
#        ticket_use  capacity      predict  total_sales
# 3        0.262220  0.320339  102063401.0     96350000
# 5        0.029947  0.023292    1935298.0      2000000
# 8        0.060389  0.087730   24435394.0     23680000
# 9        0.026234  0.051833    1447457.0      1400000
# 12       0.040837  0.468087    9061271.0      8880000
# ...           ...       ...          ...          ...
# 99743    0.039228  0.121637    9219374.0      9010000
# 99749    0.052098  0.145518   23090449.0     23220000
# 99750    0.028338  0.021367    1845996.0      1850000
# 99754    0.024502  0.221287     344673.0       300000
# 99761    0.028091  0.031641    4152501.0      4200000
#
# [19953 rows x 9 columns]

# %%
#2. XGBoost
